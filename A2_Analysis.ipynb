# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
df=pd.read_json('stat.json')

# %%
df['Heuristic Number']=df['heur_name'].str.split('_',expand=True)[1]
df['heur_short_name'] = df['heur_name'].str.split('_',expand=True)[0]
df.columns
df=df.round(3)
file_count=50

# %%
#Average Sol Path
plt.figure(figsize=(12, 8))
ax=sns.barplot(data=df[1:],x="heur_name", y="av_sol_length", palette="colorblind")
plt.xticks(rotation=45)
plt.title("Solutions Paths Average Lengths")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1, height,
            ha='center', va='bottom')
plt.ylabel('Length')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/average_sol_path_length.png')

# %%
#Total Sol Path
plt.figure(figsize=(12, 8))
ax=sns.barplot(data=df[1:],x="heur_name", y="total_sol_length", palette="colorblind")
plt.xticks(rotation=45)
plt.title("Solutions Paths Total Lengths")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1, height,
            ha='center', va='bottom')
plt.ylabel('Length')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/total_sol_path_length.png')

# %%
#Average Execution time
plt.figure(figsize=(12, 8))
ax=sns.barplot(data=df[1:],x="heur_name", y="av_execution_time", palette="colorblind")
plt.xticks(rotation=45)
plt.title("Average Execution Time for 3x3")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1, height,
            ha='center', va='bottom')
plt.ylabel('Time (s)')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/average_exec_time.png')

# %%
#Total Execution time
plt.figure(figsize=(12, 8))
ax=sns.barplot(data=df[1:],x="heur_name", y="total_execution_time", palette="colorblind")
plt.xticks(rotation=45)
plt.title("Total Execution Time")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1, height,
            ha='center', va='bottom')
plt.ylabel('Time (s)')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/total_exec_time.png')

# %%
#Average Cost
plt.figure(figsize=(12, 8))
ax=sns.barplot(data=df[1:],x="heur_name", y="av_cost", palette="colorblind")
plt.xticks(rotation=45)
plt.title("Average Solution Cost for 3x3")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1, height,
            ha='center', va='bottom')
plt.ylabel('Cost')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/average_solution_cost.png')

# %%
#Total Cost
plt.figure(figsize=(12, 8))
ax=sns.barplot(data=df[1:],x="heur_name", y="total_cost", palette="colorblind")
plt.xticks(rotation=45)
plt.title("Total Solution Cost for 3x3")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1, height,
            ha='center', va='bottom')
plt.ylabel('Cost')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/total_solution_cost.png')

# %%
#Average search path length
plt.figure(figsize=(12, 8))
ax=sns.barplot(data=df[1:],x="heur_name", y="av_search_length", palette="colorblind")
plt.xticks(rotation=45)
plt.title("Average Search Path Length")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1, height,
            ha='center', va='bottom')
plt.ylabel('Length')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/average_search_path_length.png')

# %%
#Total search path length
plt.figure(figsize=(12, 8))
ax=sns.barplot(data=df[1:],x="heur_name", y="total_search_length", palette="colorblind")
plt.xticks(rotation=45)
plt.title("Total Search Path Length")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1, height,
            ha='center', va='bottom')
plt.ylabel('Length')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/total_search_path_length.png')

# %%
sub_df=df[1:][['heur_name','n_solved','n_unsolved']]
sub_df=sub_df.append(sub_df,ignore_index=True)
sub_df['solved']=pd.Series([True,True,True,True,True,False,False,False,False,False])
sub_df['n']=sub_df['n_solved'][sub_df.solved==True]
sub_df['n'][sub_df.solved==False]=sub_df['n_unsolved'][sub_df.solved==False]
sub_df
# Out:
# <ipython-input-12-46c8dfedead1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['n'][sub_df.solved==False]=sub_df['n_unsolved'][sub_df.solved==False]
#   heur_name  n_solved  n_unsolved  solved     n
# 0    GBF_H1        50           0    True  50.0
# 1    GBF_H2        50           0    True  50.0
# 2  AStar_H1        36          14    True  36.0
# 3  AStar_H2        32          18    True  32.0
# 4    GBF_H1        50           0    True  50.0
# 5    GBF_H2        50           0   False   0.0
# 6  AStar_H1        36          14   False  14.0
# 7  AStar_H2        32          18   False  18.0

# %%
#Success Rate
plt.figure(figsize=(12, 8))

ax=sns.barplot(data=sub_df,x="heur_name", y="n",hue='solved',hue_order=[True,False], palette="colorblind")
plt.xticks(rotation=45)
plt.title("Puzzles Solved for 3x3")
for rect in ax.patches:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1,'{}, ({} %)'.format(int(height),height*100/file_count),
            ha='center', va='bottom',size=12)
    plt.savefig('Analysis_figures/3x3/success.png')
    
plt.ylabel('# of puzzles')
plt.xlabel('')
plt.savefig('Analysis_figures/3x3/success.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-4c235b245cbf> in <module>
#       7 for rect in ax.patches:
#       8     height = rect.get_height()
# ----> 9     ax.text(rect.get_x() + rect.get_width() / 2, height + 0.1,'{}, ({} %)'.format(int(height),height*100/file_count),
#      10             ha='center', va='bottom',size=12)
#      11     plt.savefig('Analysis_figures/3x3/success.png')
#
# ValueError: cannot convert float NaN to integer
